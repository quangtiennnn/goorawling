# %%
from tools import *

import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the API key
tripadvisor_api_key = os.getenv("TRIPADVISOR_API_KEY")
rapid_api_key = os.getenv("RAPID_API_KEY")

## Sub
rapid_api_key_1 = os.getenv("RAPID_API_KEY_ALT_1")
rapid_api_key_2 = os.getenv("RAPID_API_KEY_ALT_2")
rapid_api_key_3 = os.getenv("RAPID_API_KEY_ALT_3")
rapid_api_key_4 = os.getenv("RAPID_API_KEY_ALT_4")
rapid_api_key_5 = os.getenv("RAPID_API_KEY_ALT_5")

# %%
df = pd.read_csv("data/rapid_restaurant_id/Ho Chi Minh.csv", encoding="utf-8-sig",index_col=0)
print(df.shape)
df.head(2).T
# Out:
# (6045, 15)
#                                                                   0  \
# id                                                         26794670
# name                                  Phở Việt Nam - Phạm Hồng Thái
# link              https://www.tripadvisor.com/Restaurant_Review-...
# reviews                                                         200
# rating                                                          4.8
# price_range_usd                                                   $
# is_sponsored                                                   True
# menu_link                                     http://phovietnam.vn/
# reservation_link                                                NaN
# featured_image    https://dynamic-media-cdn.tripadvisor.com/medi...
# latitude                                                  10.771386
# longitude                                                 106.69614
# has_delivery                                                  False
# is_premium                                                     True
# cuisines                      ['Vietnamese', 'Soups', 'Indigenous']
#
#                                                                   1
# id                                                         26681281
# name                                                  Baieta Saigon
# link              https://www.tripadvisor.com/Restaurant_Review-...
# reviews                                                           3
# rating                                                          4.3
# price_range_usd                                            $$ - $$$
# is_sponsored                                                   True
# menu_link                                                       NaN
# reservation_link                                                NaN
# featured_image    https://dynamic-media-cdn.tripadvisor.com/medi...
# latitude                                                  10.802878
# longitude                                                 106.72722
# has_delivery                                                  False
# is_premium                                                     True
# cuisines                       ['French', 'Pizza', 'Mediterranean']

# %%
df = pd.read_csv("data/rapid_restaurant_id/Ho Chi Minh.csv", encoding="utf-8-sig",index_col=0)
print(df.shape)
# df.head(2).T
# Out:
# (6045, 15)

# %%
df = pd.read_csv("data/rapid_restaurant_id/Ho Chi Minh.csv", encoding="utf-8-sig", index_col=0)
df = df.iloc[1000:]  # Remove the first 1000 rows
print(df.shape)
df.head(2).T
# Out:
# (5045, 15)
#                                                                1000  \
# id                                                          8283378
# name                                       Banh Khot Co Ba Vung Tau
# link              https://www.tripadvisor.com/Restaurant_Review-...
# reviews                                                          69
# rating                                                          4.2
# price_range_usd                                            $$ - $$$
# is_sponsored                                                  False
# menu_link                                                       NaN
# reservation_link                                                NaN
# featured_image    https://dynamic-media-cdn.tripadvisor.com/medi...
# latitude                                                  10.771727
# longitude                                                 106.68029
# has_delivery                                                  False
# is_premium                                                    False
# cuisines                                    ['Asian', 'Vietnamese']
#
#                                                                1001
# id                                                          1902799
# name                                                 Breeze Sky Bar
# link              https://www.tripadvisor.com/Restaurant_Review-...
# reviews                                                          89
# rating                                                          4.2
# price_range_usd                                            $$ - $$$
# is_sponsored                                                  False
# menu_link                                                       NaN
# reservation_link                                                NaN
# featured_image    https://dynamic-media-cdn.tripadvisor.com/medi...
# latitude                                                  10.773095
# longitude                                                 106.70618
# has_delivery                                                  False
# is_premium                                                    False
# cuisines                                                         []

# %%
tripadvisor_api_key
# Out:
# 'B1FF7A68D064459B9A60DC001A9AC978'

# %%
# import requests

# location_id = '26681281'
# url = f"https://api.content.tripadvisor.com/api/v1/location/{location_id}/details?key={tripadvisor_api_key}&language=en&currency=USD"

# headers = {"accept": "application/json"}

# response = requests.get(url, headers=headers)

# print(response.text)

# %%
import os
import requests
import pandas as pd

def fetch_tripadvisor_details_and_save(df, n, api_key, province_name="Ho Chi Minh"):
    ids = df.id[:n]  # Get first n restaurant_id (assuming index is restaurant_id)
    records = []
    headers = {"accept": "application/json"}

    for location_id in ids:
        url = f"https://api.content.tripadvisor.com/api/v1/location/{location_id}/details?key={api_key}&language=en&currency=USD"
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            data['restaurant_id'] = location_id
            records.append(data)
        else:
            print(f"Failed for id {location_id}: {response.status_code}")

    # Save to CSV
    output_dir = os.path.join("data", "tripadvisor_restaurant")
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, f"{province_name}.csv")
    pd.DataFrame(records).set_index("restaurant_id").to_csv(output_path, encoding="utf-8-sig")
    print(f"Saved {len(records)} records to {output_path}")

# Example usage:
fetch_tripadvisor_details_and_save(df, 3000, tripadvisor_api_key, "Ho Chi Minh")
# Out:
# Failed for id 19415135: 429
# Saved 2999 records to data\tripadvisor_restaurant\Ho Chi Minh.csv

# %%
merged_df
# Out:
#                location_id                                 name  \
# restaurant_id
# 26794670          26794670        Phở Việt Nam - Phạm Hồng Thai
# 26681281          26681281                        Baieta Saigon
# 10721705          10721705                            Bếp Mẹ ỉn
# 17704147          17704147  Secret Garden Vietnamese Restaurant
# 15046046          15046046        Cloud Nine Sai Gon Restaurant
# ...                    ...                                  ...
# 8431943            8431943                        Phuong Noodle
# 26794819          26794819         PHỞ VIỆT NAM - Bui Bằng Doan
# 13786196          13786196                         Pho Ong Hung
# 20145647          20145647                   Thé Giói Tàu Hu
# 17395831          17395831                          Asia Dragon
#
#                                                          web_url  \
# restaurant_id
# 26794670       https://www.tripadvisor.com/Restaurant_Review-...
# 26681281       https://www.tripadvisor.com/Restaurant_Review-...
# 10721705       https://www.tripadvisor.com/Restaurant_Review-...
# 17704147       https://www.tripadvisor.com/Restaurant_Review-...
# 15046046       https://www.tripadvisor.com/Restaurant_Review-...
# ...                                                          ...
# 8431943        https://www.tripadvisor.com/Restaurant_Review-...
# 26794819       https://www.tripadvisor.com/Restaurant_Review-...
# 13786196       https://www.tripadvisor.com/Restaurant_Review-...
# 20145647       https://www.tripadvisor.com/Restaurant_Review-...
# 17395831       https://www.tripadvisor.com/Restaurant_Review-...
#
#                                                      address_obj  \
# restaurant_id
# 26794670       {'street1': '14 Pham Hong Thai', 'street2': 'P...
# 26681281       {'street1': '16/8 Nguyen Van Huong', 'city': '...
# 10721705       {'street1': '136/9 Du_ng Le Thanh Ton', 'city'...
# 17704147       {'street1': '19 Le Cong Kieu Street', 'city': ...
# 15046046       {'street1': '180 -188 Ly Tu Trong Street', 'st...
# ...                                                          ...
# 8431943        {'street1': 'No.6, road no. 35, Binh An ward, ...
# 26794819       {'street1': 'S36-1 Bui B_ng Doan, Tan Phong Wa...
# 13786196       {'street1': '30 Bo Bao Tan Thang', 'street2': ...
# 20145647       {'street1': '122D Tr_n Dinh Xu', 'street2': 'P...
# 17395831       {'street1': '88 Song Hanh', 'street2': '3rd Fl...
#
#                                                        ancestors   latitude  \
# restaurant_id
# 26794670       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.771386
# 26681281       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.802878
# 10721705       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.773849
# 17704147       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.768849
# 15046046       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.773206
# ...                                                          ...        ...
# 8431943        [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.836167
# 26794819       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.730942
# 13786196       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.803900
# 20145647       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.762492
# 17395831       [{'level': 'City', 'name': 'Ho Chi Minh City',...  10.734300
#
#                 longitude          timezone                             email  \
# restaurant_id
# 26794670       106.696140  Asia/Ho_Chi_Minh             phohomemade@gmail.com
# 26681281       106.727220  Asia/Ho_Chi_Minh                               NaN
# 10721705       106.698060  Asia/Ho_Chi_Minh                      info@mein.vn
# 17704147       106.698390  Asia/Ho_Chi_Minh  secretgarden.2ndbranch@gmail.com
# 15046046       106.695670  Asia/Ho_Chi_Minh          saigon@lasiestahotels.vn
# ...                   ...               ...                               ...
# 8431943        106.779564  Asia/Ho_Chi_Minh                               NaN
# 26794819       106.708640  Asia/Ho_Chi_Minh             phohomemade@gmail.com
# 13786196       106.622370  Asia/Ho_Chi_Minh                               NaN
# 20145647       106.688510  Asia/Ho_Chi_Minh            thegioitauhu@gmail.com
# 17395831       106.625780  Asia/Ho_Chi_Minh                               NaN
#
#                           phone  ... price_level  \
# restaurant_id                    ...
# 26794670       +84 90 268 22 14  ...           $
# 26681281       +84 90 270 08 63  ...    $$ - $$$
# 10721705       +84 28 2211 1119  ...           $
# 17704147       +84 28 3620 5525  ...    $$ - $$$
# 15046046       +84 28 3535 4461  ...        $$$$
# ...                         ...  ...         ...
# 8431943                     NaN  ...         NaN
# 26794819       +84 90 929 74 00  ...           $
# 13786196                    NaN  ...         NaN
# 20145647       +84 98 909 78 37  ...         NaN
# 17395831       +84 28 2220 8138  ...         NaN
#
#                                                            hours  \
# restaurant_id
# 26794670       {'periods': [{'open': {'day': 1, 'time': '0600...
# 26681281       {'periods': [{'open': {'day': 2, 'time': '1100...
# 10721705       {'periods': [{'open': {'day': 1, 'time': '1030...
# 17704147       {'periods': [{'open': {'day': 1, 'time': '1000...
# 15046046       {'periods': [{'open': {'day': 1, 'time': '0630...
# ...                                                          ...
# 8431943                                                      NaN
# 26794819       {'periods': [{'open': {'day': 1, 'time': '0600...
# 13786196                                                     NaN
# 20145647                                                     NaN
# 17395831                                                     NaN
#
#                                                         features  \
# restaurant_id
# 26794670       ['Accepts Credit Cards', 'Visa', 'Delivery', '...
# 26681281       ['Accepts Credit Cards', 'Delivery', 'Dog Frie...
# 10721705       ['Accepts Credit Cards', 'Mastercard', 'Visa',...
# 17704147       ['Accepts Credit Cards', 'Mastercard', 'Visa',...
# 15046046       ['Full Bar', 'Outdoor Seating', 'Reservations'...
# ...                                                          ...
# 8431943                                                       []
# 26794819                                                      []
# 13786196                                                      []
# 20145647                                                      []
# 17395831                                                      []
#
#                                                          cuisine  \
# restaurant_id
# 26794670       [{'name': 'vietnamese', 'localized_name': 'Vie...
# 26681281       [{'name': 'french', 'localized_name': 'French'...
# 10721705       [{'name': 'vietnamese', 'localized_name': 'Vie...
# 17704147       [{'name': 'asian', 'localized_name': 'Asian'},...
# 15046046       [{'name': 'fast_food', 'localized_name': 'Fast...
# ...                                                          ...
# 8431943                                                       []
# 26794819       [{'name': 'vietnamese', 'localized_name': 'Vie...
# 13786196                                                      []
# 20145647       [{'name': 'vietnamese', 'localized_name': 'Vie...
# 17395831       [{'name': 'chinese', 'localized_name': 'Chines...
#
#                                                         category  \
# restaurant_id
# 26794670       {'name': 'restaurant', 'localized_name': 'Rest...
# 26681281       {'name': 'restaurant', 'localized_name': 'Rest...
# 10721705       {'name': 'restaurant', 'localized_name': 'Rest...
# 17704147       {'name': 'restaurant', 'localized_name': 'Rest...
# 15046046       {'name': 'restaurant', 'localized_name': 'Rest...
# ...                                                          ...
# 8431943        {'name': 'restaurant', 'localized_name': 'Rest...
# 26794819       {'name': 'restaurant', 'localized_name': 'Rest...
# 13786196       {'name': 'restaurant', 'localized_name': 'Rest...
# 20145647       {'name': 'restaurant', 'localized_name': 'Rest...
# 17395831       {'name': 'restaurant', 'localized_name': 'Rest...
#
#                                                      subcategory  \
# restaurant_id
# 26794670                                                      []
# 26681281       [{'name': 'sit_down', 'localized_name': 'Sit d...
# 10721705       [{'name': 'sit_down', 'localized_name': 'Sit d...
# 17704147       [{'name': 'sit_down', 'localized_name': 'Sit d...
# 15046046            [{'name': 'cafe', 'localized_name': 'Café'}]
# ...                                                          ...
# 8431943                                                       []
# 26794819       [{'name': 'sit_down', 'localized_name': 'Sit d...
# 13786196                                                      []
# 20145647                                                      []
# 17395831                                                      []
#
#               neighborhood_info  \
# restaurant_id
# 26794670                     []
# 26681281                     []
# 10721705                     []
# 17704147                     []
# 15046046                     []
# ...                         ...
# 8431943                      []
# 26794819                     []
# 13786196                     []
# 20145647                     []
# 17395831                     []
#
#                                                       trip_types  \
# restaurant_id
# 26794670       [{'name': 'business', 'localized_name': 'Busin...
# 26681281       [{'name': 'business', 'localized_name': 'Busin...
# 10721705       [{'name': 'business', 'localized_name': 'Busin...
# 17704147       [{'name': 'business', 'localized_name': 'Busin...
# 15046046       [{'name': 'business', 'localized_name': 'Busin...
# ...                                                          ...
# 8431943        [{'name': 'business', 'localized_name': 'Busin...
# 26794819       [{'name': 'business', 'localized_name': 'Busin...
# 13786196       [{'name': 'business', 'localized_name': 'Busin...
# 20145647       [{'name': 'business', 'localized_name': 'Busin...
# 17395831       [{'name': 'business', 'localized_name': 'Busin...
#
#                                                           awards  \
# restaurant_id
# 26794670                                                      []
# 26681281                                                      []
# 10721705       [{'award_type': 'Travelers Choice', 'year': '2...
# 17704147       [{'award_type': 'Travelers Choice', 'year': '2...
# 15046046       [{'award_type': 'Travelers Choice', 'year': '2...
# ...                                                          ...
# 8431943                                                       []
# 26794819                                                      []
# 13786196                                                      []
# 20145647                                                      []
# 17395831                                                      []
#
#                                                      description
# restaurant_id
# 26794670                                                     NaN
# 26681281       A riverside escape in Thảo Điền, Baïeta brings...
# 10721705       It is all about Vietnamese food. Lovely staff ...
# 17704147       Warmly welcome you to the newly renovated Secr...
# 15046046       A chic and intimate space living up to its nam...
# ...                                                          ...
# 8431943                                                      NaN
# 26794819                                                     NaN
# 13786196                                                     NaN
# 20145647                                                     NaN
# 17395831                                                     NaN
#
# [3999 rows x 30 columns]
